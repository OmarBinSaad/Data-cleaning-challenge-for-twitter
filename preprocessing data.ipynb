# %% [markdown]
# <a href="https://colab.research.google.com/github/OmarBinSaad/OmarBinSaad/blob/main/preprocessing%20data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use("ggplot")

# %%
insert = {"name":["mike jamal","tays fahad","majed abdo","samy ramy","Mmar saad"],
     "Age":["25","32","12","41","85"],
     "Conttrry":["UK","EGY","UK","EGY","KSA"],
     "M/F":["M","F","M","F","M"],
     "Email":["AB@gmail.com","C@gmail.com","D@gmail.com","AP@gmail.com","A@gmail.com"],
     "buy":["Yes","No","no","Yes","No"]}

df = pd.DataFrame(insert)
df
# Out:
#          name Age Conttrry M/F         Email  buy
# 0  mike jamal  25       UK   M  AB@gmail.com  Yes
# 1  tays fahad  32      EGY   F   C@gmail.com   No
# 2  majed abdo  12       UK   M   D@gmail.com   no
# 3   samy ramy  41      EGY   F  AP@gmail.com  Yes
# 4   Mmar saad  85      KSA   M   A@gmail.com   No

# %%
df.rename(columns={"name":"Name"}, inplace=True)
df
# Out:
#          Name Age Conttrry M/F         Email  buy
# 0  mike jamal  25       UK   M  AB@gmail.com  Yes
# 1  tays fahad  32      EGY   F   C@gmail.com   No
# 2  majed abdo  12       UK   M   D@gmail.com   no
# 3   samy ramy  41      EGY   F  AP@gmail.com  Yes
# 4   Mmar saad  85      KSA   M   A@gmail.com   No

# %%
df["First_Name"] = df["Name"].str.split(" ").str.get(0)

# %%
df["Last_Name"] = df["Name"].str.split(" ").str.get(1)

# %%
df
# Out:
#          Name Age Conttrry M/F         Email  buy First_Name Last_Name
# 0  mike jamal  25       UK   M  AB@gmail.com  Yes       mike     jamal
# 1  tays fahad  32      EGY   F   C@gmail.com   No       tays     fahad
# 2  majed abdo  12       UK   M   D@gmail.com   no      majed      abdo
# 3   samy ramy  41      EGY   F  AP@gmail.com  Yes       samy      ramy
# 4   Mmar saad  85      KSA   M   A@gmail.com   No       Mmar      saad

# %%
df["First_Name"] = df["First_Name"].str.capitalize()

# %%
df["Last_Name"] = df["Last_Name"].str.capitalize()

# %%
df
# Out:
#          Name Age Conttrry M/F         Email  buy First_Name Last_Name
# 0  mike jamal  25       UK   M  AB@gmail.com  Yes       Mike     Jamal
# 1  tays fahad  32      EGY   F   C@gmail.com   No       Tays     Fahad
# 2  majed abdo  12       UK   M   D@gmail.com   no      Majed      Abdo
# 3   samy ramy  41      EGY   F  AP@gmail.com  Yes       Samy      Ramy
# 4   Mmar saad  85      KSA   M   A@gmail.com   No       Mmar      Saad

# %%
df.drop("Name", axis = 1, inplace=True)

# %%
df
# Out:
#   Age Conttrry M/F         Email  buy First_Name Last_Name
# 0  25       UK   M  AB@gmail.com  Yes       Mike     Jamal
# 1  32      EGY   F   C@gmail.com   No       Tays     Fahad
# 2  12       UK   M   D@gmail.com   no      Majed      Abdo
# 3  41      EGY   F  AP@gmail.com  Yes       Samy      Ramy
# 4  85      KSA   M   A@gmail.com   No       Mmar      Saad

# %%
df = df[["First_Name","Last_Name","M/F","Age","buy","Email","Conttrry"]]

# %%
df
# Out:
#   First_Name Last_Name M/F Age  buy         Email Conttrry
# 0       Mike     Jamal   M  25  Yes  AB@gmail.com       UK
# 1       Tays     Fahad   F  32   No   C@gmail.com      EGY
# 2      Majed      Abdo   M  12   no   D@gmail.com       UK
# 3       Samy      Ramy   F  41  Yes  AP@gmail.com      EGY
# 4       Mmar      Saad   M  85   No   A@gmail.com      KSA

# %%
df.rename(columns={"M/F":"Gender"},inplace=True)

# %%
df
# Out:
#   First_Name Last_Name Gender Age  buy         Email Conttrry
# 0       Mike     Jamal      M  25  Yes  AB@gmail.com       UK
# 1       Tays     Fahad      F  32   No   C@gmail.com      EGY
# 2      Majed      Abdo      M  12   no   D@gmail.com       UK
# 3       Samy      Ramy      F  41  Yes  AP@gmail.com      EGY
# 4       Mmar      Saad      M  85   No   A@gmail.com      KSA

# %%
df["Gender"] = df["Gender"].str.replace("M","Male").str.replace("F","Female")

# %%
df
# Out:
#   First_Name Last_Name  Gender Age  buy         Email Conttrry
# 0       Mike     Jamal    Male  25  Yes  AB@gmail.com       UK
# 1       Tays     Fahad  Female  32   No   C@gmail.com      EGY
# 2      Majed      Abdo    Male  12   no   D@gmail.com       UK
# 3       Samy      Ramy  Female  41  Yes  AP@gmail.com      EGY
# 4       Mmar      Saad    Male  85   No   A@gmail.com      KSA

# %%
df.rename(columns={"buy":"purchase"}, inplace=True)

# %%
pd.get_dummies(df["purchase"])
# Out:
#    No  Yes  no
# 0   0    1   0
# 1   1    0   0
# 2   0    0   1
# 3   0    1   0
# 4   1    0   0

# %%
df["purchase"] = df["purchase"].str.capitalize()

# %%
df
# Out:
#   First_Name Last_Name  Gender Age purchase         Email Conttrry
# 0       Mike     Jamal    Male  25      Yes  AB@gmail.com       UK
# 1       Tays     Fahad  Female  32       No   C@gmail.com      EGY
# 2      Majed      Abdo    Male  12       No   D@gmail.com       UK
# 3       Samy      Ramy  Female  41      Yes  AP@gmail.com      EGY
# 4       Mmar      Saad    Male  85       No   A@gmail.com      KSA

# %%
pd.get_dummies(df["purchase"])
# Out:
#    No  Yes
# 0   0    1
# 1   1    0
# 2   1    0
# 3   0    1
# 4   1    0

# %%
pd.get_dummies(df["purchase"], drop_first=True).rename({"Yes":"purchase"}, axis= 1)
# Out:
#    purchase
# 0         1
# 1         0
# 2         0
# 3         1
# 4         0

# %%
df["purchase"] = pd.get_dummies(df["purchase"], drop_first=True).rename({"Yes":"purchase"}, axis= 1)

# %%
df
# Out:
#   First_Name Last_Name  Gender Age  purchase         Email Conttrry
# 0       Mike     Jamal    Male  25         1  AB@gmail.com       UK
# 1       Tays     Fahad  Female  32         0   C@gmail.com      EGY
# 2      Majed      Abdo    Male  12         0   D@gmail.com       UK
# 3       Samy      Ramy  Female  41         1  AP@gmail.com      EGY
# 4       Mmar      Saad    Male  85         0   A@gmail.com      KSA

# %%
df["Email"] = df["Email"].str.lower()

# %%
df
# Out:
#   First_Name Last_Name  Gender Age  purchase         Email Conttrry
# 0       Mike     Jamal    Male  25         1  ab@gmail.com       UK
# 1       Tays     Fahad  Female  32         0   c@gmail.com      EGY
# 2      Majed      Abdo    Male  12         0   d@gmail.com       UK
# 3       Samy      Ramy  Female  41         1  ap@gmail.com      EGY
# 4       Mmar      Saad    Male  85         0   a@gmail.com      KSA

# %%
df.rename({"Conttrry":"Country"},axis = 1, inplace = True)
df
# Out:
#   First_Name Last_Name  Gender Age  purchase         Email Country
# 0       Mike     Jamal    Male  25         1  ab@gmail.com      UK
# 1       Tays     Fahad  Female  32         0   c@gmail.com     EGY
# 2      Majed      Abdo    Male  12         0   d@gmail.com      UK
# 3       Samy      Ramy  Female  41         1  ap@gmail.com     EGY
# 4       Mmar      Saad    Male  85         0   a@gmail.com     KSA

# %%
df.to_csv('Final.csv')
